# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid

import numpy as np
import pandas as pd
import seaborn as sn  # for heatmaps
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
transform = transforms.ToTensor()

# %%
train_data = datasets.CIFAR10(root='../Data', train=True, download=True, transform=transform)
# Out:
# Files already downloaded and verified

# %%
test_data = datasets.CIFAR10(root='../Data', train=False, download=True, transform=transform)
# Out:
# Files already downloaded and verified

# %%
train_data
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ../Data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
test_data
# Out:
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: ../Data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()

# %%
torch.manual_seed(101)

# %%
train_loader = DataLoader(train_data, batch_size=10, shuffle=True)
test_loader = DataLoader(test_data, batch_size=10, shuffle=False)

# %%
class_names = ['plane', '  car', ' bird', '  cat', ' deer', '  dog', ' frog', 'horse', ' ship', 'truck']

# %%
for images, labels in train_loader:
    break

# %%
labels
# Out:
# tensor([9, 5, 2, 3, 0, 5, 9, 5, 1, 6])

# %%
print(labels)

im = make_grid(images,nrow=10)
plt.figure(figsize=(20,4))
plt.imshow(np.transpose(im.numpy(),(1,2,0)))
# Out:
# tensor([9, 5, 2, 3, 0, 5, 9, 5, 1, 6])

# %%
class ConvolutionalNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.fconv1 = nn.Conv2d(3,6,5,1)
        self.fconv2 = nn.Conv2d(6,16,3,1)
        self.fc1 = nn.Linear(6*6*16,120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84,10)
        
    def forward(self, X):
        X = F.relu(self.fconv1(X))
        X = F.max_pool2d(X,2,2)
        X = F.relu(self.fconv2(X))
        X = F.max_pool2d(X,2,2)
        X = X.view(-1, 6*6*16)
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        
        return F.log_softmax(X,dim=1)

# %%
torch.manual_seed(101)
model = ConvolutionalNetwork()
model
# Out:
# ConvolutionalNetwork(
#   (fconv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (fconv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=576, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
sum_param = []
for idx, param in enumerate(model.parameters()):
    sum_param.append(param.numel())
    print(f"Element {idx+1}: {param.numel()}")
print(f"Sum of all elements = {sum(sum_param)}")
# Out:
# Element 1: 450
# Element 2: 6
# Element 3: 864
# Element 4: 16
# Element 5: 69120
# Element 6: 120
# Element 7: 10080
# Element 8: 84
# Element 9: 840
# Element 10: 10
# Sum of all elements = 81590

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
import time
start_time = time.time()

epochs = 10
train_losses = []
test_losses = []
train_correct = []
test_correct = []

for i in range(epochs):
    trn_corr = 0
    tst_corr = 0
    
    # Run the training batches
    for b, (X_train, y_train) in enumerate(train_loader):
        b+=1
        
        # Apply the model
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
 
        # Tally the number of correct predictions
        predicted = torch.max(y_pred.data, 1)[1]
        batch_corr = (predicted == y_train).sum()
        trn_corr += batch_corr
        
        # Update parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Print interim results
        if b%1000 == 0:
            print(f'epoch: {i:2}  batch: {b:4} [{10*b:6}/50000]  loss: {loss.item():10.8f}  \
accuracy: {trn_corr.item()*100/(10*b):7.3f}%')
        
    train_losses.append(loss)
    train_correct.append(trn_corr)
        
    # Run the testing batches
    with torch.no_grad():
        for b, (X_test, y_test) in enumerate(test_loader):

            # Apply the model
            y_val = model(X_test)

            # Tally the number of correct predictions
            predicted = torch.max(y_val.data, 1)[1] 
            tst_corr += (predicted == y_test).sum()
            
    loss = criterion(y_val, y_test)
    test_losses.append(loss)
    test_correct.append(tst_corr)
        
print(f'\nDuration: {time.time() - start_time:.0f} seconds') # print the time elapsed
# Out:
# epoch:  0  batch: 1000 [ 10000/50000]  loss: 2.22062516  accuracy:  24.900%
# epoch:  0  batch: 2000 [ 20000/50000]  loss: 1.70107234  accuracy:  31.965%
# epoch:  0  batch: 3000 [ 30000/50000]  loss: 1.04979932  accuracy:  35.507%
# epoch:  0  batch: 4000 [ 40000/50000]  loss: 1.11525655  accuracy:  37.920%
# epoch:  0  batch: 5000 [ 50000/50000]  loss: 1.60285950  accuracy:  39.506%
# epoch:  1  batch: 1000 [ 10000/50000]  loss: 1.40958893  accuracy:  48.010%
# epoch:  1  batch: 2000 [ 20000/50000]  loss: 1.11808276  accuracy:  49.485%
# epoch:  1  batch: 3000 [ 30000/50000]  loss: 1.23309684  accuracy:  50.270%
# epoch:  1  batch: 4000 [ 40000/50000]  loss: 1.60422611  accuracy:  51.047%
# epoch:  1  batch: 5000 [ 50000/50000]  loss: 1.42299533  accuracy:  51.476%
# epoch:  2  batch: 1000 [ 10000/50000]  loss: 1.54366446  accuracy:  57.040%
# epoch:  2  batch: 2000 [ 20000/50000]  loss: 1.30475223  accuracy:  56.310%
# epoch:  2  batch: 3000 [ 30000/50000]  loss: 1.21324849  accuracy:  56.137%
# epoch:  2  batch: 4000 [ 40000/50000]  loss: 0.79735786  accuracy:  56.267%
# epoch:  2  batch: 5000 [ 50000/50000]  loss: 1.56623411  accuracy:  56.466%
# epoch:  3  batch: 1000 [ 10000/50000]  loss: 0.78165281  accuracy:  59.990%
# epoch:  3  batch: 2000 [ 20000/50000]  loss: 1.01374948  accuracy:  58.885%
# epoch:  3  batch: 3000 [ 30000/50000]  loss: 1.98782754  accuracy:  58.770%
# epoch:  3  batch: 4000 [ 40000/50000]  loss: 0.94419575  accuracy:  58.602%
# epoch:  3  batch: 5000 [ 50000/50000]  loss: 0.88972819  accuracy:  58.736%
# epoch:  4  batch: 1000 [ 10000/50000]  loss: 0.73900872  accuracy:  60.910%
# epoch:  4  batch: 2000 [ 20000/50000]  loss: 1.04852247  accuracy:  60.715%
# epoch:  4  batch: 3000 [ 30000/50000]  loss: 1.36725402  accuracy:  60.653%
# epoch:  4  batch: 4000 [ 40000/50000]  loss: 0.62252998  accuracy:  60.935%
# epoch:  4  batch: 5000 [ 50000/50000]  loss: 0.93130410  accuracy:  61.044%
# epoch:  5  batch: 1000 [ 10000/50000]  loss: 1.32590890  accuracy:  63.110%
# epoch:  5  batch: 2000 [ 20000/50000]  loss: 0.84381074  accuracy:  62.920%
# epoch:  5  batch: 3000 [ 30000/50000]  loss: 1.03372312  accuracy:  62.460%
# epoch:  5  batch: 4000 [ 40000/50000]  loss: 0.67028576  accuracy:  62.195%
# epoch:  5  batch: 5000 [ 50000/50000]  loss: 1.01304102  accuracy:  62.046%
# epoch:  6  batch: 1000 [ 10000/50000]  loss: 0.94172418  accuracy:  64.080%
# epoch:  6  batch: 2000 [ 20000/50000]  loss: 1.41785014  accuracy:  63.485%
# epoch:  6  batch: 3000 [ 30000/50000]  loss: 0.88304645  accuracy:  63.410%
# epoch:  6  batch: 4000 [ 40000/50000]  loss: 1.17392349  accuracy:  63.480%
# epoch:  6  batch: 5000 [ 50000/50000]  loss: 0.64167917  accuracy:  63.386%
# epoch:  7  batch: 1000 [ 10000/50000]  loss: 1.78067040  accuracy:  65.260%
# epoch:  7  batch: 2000 [ 20000/50000]  loss: 0.97767842  accuracy:  64.955%
# epoch:  7  batch: 3000 [ 30000/50000]  loss: 2.53121853  accuracy:  64.777%
# epoch:  7  batch: 4000 [ 40000/50000]  loss: 1.30975282  accuracy:  64.683%
# epoch:  7  batch: 5000 [ 50000/50000]  loss: 1.65896821  accuracy:  64.446%
# epoch:  8  batch: 1000 [ 10000/50000]  loss: 1.43367255  accuracy:  66.290%
# epoch:  8  batch: 2000 [ 20000/50000]  loss: 1.88527203  accuracy:  66.070%
# epoch:  8  batch: 3000 [ 30000/50000]  loss: 1.19507766  accuracy:  65.617%
# epoch:  8  batch: 4000 [ 40000/50000]  loss: 0.87499893  accuracy:  65.640%
# epoch:  8  batch: 5000 [ 50000/50000]  loss: 1.36313879  accuracy:  65.342%
# epoch:  9  batch: 1000 [ 10000/50000]  loss: 0.65352982  accuracy:  67.320%
# epoch:  9  batch: 2000 [ 20000/50000]  loss: 1.66320395  accuracy:  66.640%
# epoch:  9  batch: 3000 [ 30000/50000]  loss: 1.15694773  accuracy:  66.727%
# epoch:  9  batch: 4000 [ 40000/50000]  loss: 1.80921113  accuracy:  66.377%
# epoch:  9  batch: 5000 [ 50000/50000]  loss: 0.98208588  accuracy:  66.148%
#
# Duration: 161 seconds

# %%
#save the model
torch.save(model.state_dict(), 'my_CIFARmodel.pt')

# %%
plt.plot(train_losses, label="Training loss")
plt.plot(test_losses, label="Testing loss")
plt.title("Loss at the end of each epoch")
plt.legend()

# %%
plt.plot([t/500 for t in train_correct], label='training accuracy')
plt.plot([t/100 for t in test_correct], label='validation accuracy')
plt.title('Accuracy at the end of each epoch')
plt.legend();

# %%
print(test_correct)
# Out:
# [tensor(4771), tensor(5442), tensor(5686), tensor(5834), tensor(5826), tensor(6019), tensor(5990), tensor(6023), tensor(6023), tensor(6140)]

# %%
num_c = test_correct[-1].item()

# %%
num_c * 100 / 10000
# Out:
# 61.4

# %%
# Create a loader for the entire the test set
test_load_all = DataLoader(test_data, batch_size=10000, shuffle=False)

with torch.no_grad():
    correct = 0
    for X_test, y_test in test_load_all:
        y_val = model(X_test)
        predicted = torch.max(y_val,1)[1]
        correct += (predicted == y_test).sum()

arr = confusion_matrix(y_test.view(-1), predicted.view(-1))
df_cm = pd.DataFrame(arr, class_names, class_names)
plt.figure(figsize = (9,6))
sn.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("prediction")
plt.ylabel("label (ground truth)")
plt.show();
